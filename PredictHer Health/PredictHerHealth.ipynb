# %% [markdown]
# ## **PredictHer Health: Advanced Machine Learning for Early Breast Cancer Detection**
#
# **Nazmul Farooquee**

# %% [markdown]
# ### Project Summary
# **PredictHer Health** is a cutting-edge data science initiative aimed at enhancing early detection and diagnosis of breast cancer using advanced machine learning techniques. By analyzing a comprehensive dataset of breast cancer features, the project aims to develop a highly accurate predictive model that can serve as a valuable tool for healthcare professionals. The project encompasses a full data science pipeline including data preprocessing, exploratory data analysis, model training, evaluation, and deployment, with the ultimate goal of providing a reliable, scalable solution for breast cancer prediction.
#
# ### Scope of the Project
# **PredictHer Health** includes the following key components:
#
# 1. **Data Preprocessing**:
#    - Clean and handle missing data to ensure dataset integrity.
#    - Encode categorical variables to convert them into numerical format.
#    - Scale features to standardize data for improved model performance.
#
# 2. **Exploratory Data Analysis (EDA)**:
#    - Visualize feature distributions to understand data patterns.
#    - Analyze correlations between features to identify significant relationships.
#    - Investigate the relationship between features and the target variable (diagnosis) to gain deeper insights.
#
# 3. **Model Training and Evaluation**:
#    - Implement and train various machine learning models (Logistic Regression, Decision Tree, Random Forest).
#    - Compare model performances using metrics such as accuracy, precision, recall, and F1-score.
#    - Select the best-performing model based on evaluation results.
#
# 4. **Model Deployment**:
#    - Save the trained model for future use.
#    - Develop a prediction pipeline to facilitate real-time predictions on new data.
#
# 5. **Documentation and Reporting**:
#    - Thoroughly document each step of the process.
#    - Prepare a detailed report summarizing findings, methodologies, and model performance.
#
# ### Potential Users
# **PredictHer Health** is designed to benefit a wide range of stakeholders within the healthcare industry:
#
# 1. **Healthcare Providers**:
#    - Oncologists and general practitioners can use the predictive model to assist in early breast cancer diagnosis, improving treatment outcomes.
#    - Radiologists can integrate the model with imaging technologies to enhance diagnostic accuracy.
#
# 2. **Medical Researchers**:
#    - Researchers can utilize the model and dataset for further studies on breast cancer, contributing to advancements in medical science.
#    - Academic institutions can leverage the project as a foundation for developing more sophisticated predictive models.
#
# 3. **Healthcare Institutions**:
#    - Hospitals and clinics can incorporate the predictive model into their diagnostic workflows to enhance efficiency and accuracy.
#    - Health technology companies can integrate the model into their diagnostic tools and platforms, offering improved services to clients.
#
# 4. **Patients**:
#    - Individuals can benefit from earlier detection and diagnosis, leading to timely and more effective treatment options.
#    - Patient advocacy groups can use the project's findings to raise awareness and promote early screening initiatives.
#
# ### Future of the Project
# The future of **PredictHer Health** holds significant potential for advancement and broader impact:
#
# 1. **Integration with Advanced Imaging Techniques**:
#    - Combine imaging data (e.g., mammograms) with existing datasets to improve prediction accuracy.
#    - Employ deep learning techniques for sophisticated image analysis and feature extraction.
#
# 2. **Model Optimization and Expansion**:
#    - Continuously update and optimize the model with new data to enhance accuracy and generalizability.
#    - Expand the model’s capabilities to predict other types of cancer or medical conditions.
#
# 3. **Clinical Deployment**:
#    - Develop a user-friendly interface for healthcare providers to use the predictive model seamlessly in clinical settings.
#    - Ensure the model complies with regulatory standards and clinical best practices.
#
# 4. **Collaboration and Open Source**:
#    - Collaborate with medical researchers, institutions, and industry partners to refine and validate the model.
#    - Release the project as an open-source tool to foster community contributions and continuous improvement.
#
# 5. **Personalized Medicine**:
#    - Explore personalized prediction models tailored to individual patient data for more precise and relevant predictions.
#    - Integrate genomic data to provide comprehensive risk assessments and personalized treatment plans.
#
# **PredictHer Health** aims to revolutionize breast cancer detection and diagnosis, harnessing the power of machine learning to improve healthcare outcomes and save lives. Through ongoing innovation and collaboration, this project has the potential to make a lasting impact on medical diagnostics and patient care.
#
#
# **Disclaimer**
#
# The dataset used in this project is sourced from the UCI Machine Learning Repository and consists of anonymized breast cancer diagnostic data. The features in the dataset are derived from digitized images of fine needle aspirate (FNA) of breast mass and describe characteristics of the cell nuclei present in the images. The dataset includes 569 instances, with 357 benign and 212 malignant cases. All results and findings are based on this specific dataset and may not be generalizable to other datasets or real-world scenarios without further validation.

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# ### 1.1 Clean and Handle Missing Data
#
# First, let's load the data and inspect it for missing values. We'll handle any missing data to ensure dataset integrity.

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
df = pd.read_csv("data.csv")

# Display the first few rows of the dataset
print(df.head())

# Check for missing values
print(df.info())

# Count the number of missing values in each column
print(df.isna().sum())

# Drop the column with all NaN values
df = df.dropna(axis=1)

# Verify that the column has been removed
print(df.info())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Observations from the Output:
#
# #### Initial Data Check:
# - The dataset contains 569 entries with 33 columns.
# - The columns include various features such as `id`, `diagnosis`, `radius_mean`, `texture_mean`, etc.
#
# #### Missing Values Check:
# - The `Unnamed: 32` column has all 569 values missing (NaN).
# - Other columns do not have missing values.
#
# #### Dropping Columns with All NaN Values:
# - After dropping the `Unnamed: 32` column, the DataFrame now has 32 columns.
#
# #### Final Data Check:
# - The `df.info()` output confirms that the `Unnamed: 32` column has been successfully removed.
# - All remaining columns have 569 non-null values, indicating no missing data in these columns.

# %% [markdown]
# ### Step 1.2 Encode Categorical Variables
#
# Next, we'll encode the categorical variable 'diagnosis' to convert it into numerical format. This step is necessary for machine learning algorithms to process the data.

# %%
# Import LabelEncoder from sklearn
from sklearn.preprocessing import LabelEncoder

# Encode the 'diagnosis' column
labelencoder_Y = LabelEncoder()
df.iloc[:, 1] = labelencoder_Y.fit_transform(df.iloc[:, 1].values)

# Display the first few rows to verify encoding
print(df.head())
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         1        17.99         10.38          122.80     1001.0
# 1    842517         1        20.57         17.77          132.90     1326.0
# 2  84300903         1        19.69         21.25          130.00     1203.0
# 3  84348301         1        11.42         20.38           77.58      386.1
# 4  84358402         1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Observations from the Output:
#
# - The 'diagnosis' column, originally containing 'M' and 'B', is now encoded as 1 and 0, respectively.
# - The dataframe structure remains the same, with the 'diagnosis' column successfully transformed into a numerical format.

# %% [markdown]
# ### Step 1.3 Scale Features
#
# Finally, we'll scale the features to standardize the data. This step is important to improve the performance of machine learning models, especially those sensitive to feature scaling.

# %%
# Import StandardScaler from sklearn
from sklearn.preprocessing import StandardScaler

# Separate the features and labels
X = df.iloc[:, 2:31].values
Y = df.iloc[:, 1].values

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# Scale the features
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Verify scaling by printing the first few rows of X_train
print(X_train[:5])
# Out:
# [[-1.15036482 -0.39064196 -1.12855021 -0.95876358  0.3109837  -0.5959945
#   -0.80259612 -0.80249002  0.29453906  0.0942515  -0.4950523   1.48720153
#   -0.51448782 -0.49154005  0.28149837 -0.60451206 -0.46900701 -0.61170002
#    0.05798237 -0.35763702 -1.0431756   0.21353282 -1.0360446  -0.84880771
#    0.34249851 -0.73009743 -0.81232053 -0.75798367 -0.01614761]
#  [-0.93798972  0.68051405 -0.94820146 -0.82152548 -0.60963604 -0.90986721
#   -0.66066905 -0.89871612  0.75493453 -0.42547082 -0.33381757  0.75941203
#   -0.28751805 -0.42127695 -0.1620797  -0.20486693 -0.05029632 -0.20309076
#   -0.25469005 -0.39139463 -0.71565415  1.06684183 -0.68992205 -0.66869703
#   -0.09553745 -0.53786647 -0.37504806 -0.60687023  0.09669004]
#  [ 0.574121   -1.03333557  0.51394098  0.40858627 -0.10616078 -0.36301886
#   -0.41799048 -0.08844569 -0.27182044 -0.57522132 -0.57672579 -1.05784511
#   -0.53856037 -0.38708923 -1.07211882 -0.72057496 -0.42362791 -0.49218988
# ...

# %% [markdown]
# ### Observations from the Output:
#
# - The features have been successfully scaled to have a mean of 0 and a standard deviation of 1.
# - Scaling ensures that the data is standardized, which can improve the performance of many machine learning algorithms.

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**
#
# In this step, we will visualize the data and analyze correlations between features to gain insights and identify patterns in the dataset.

# %% [markdown]
# #### Step 2.1 Visualize Feature Distributions
#
# We'll start by visualizing the distribution of features to understand their behavior.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Plot distribution for selected features
features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean']
df[features].hist(bins=15, figsize=(15, 10), layout=(3, 2))
plt.suptitle('Feature Distributions', fontsize=16)
plt.show()

# %% [markdown]
# **Observations from the Output:**
#
# #### Visualizations of Feature Distributions
#
# 1. **radius_mean**:
#    - The distribution is right-skewed, with most values concentrated between 10 and 20.
#    - There are a few outliers with values greater than 25.
#
# 2. **texture_mean**:
#    - This feature also shows a right-skewed distribution, with most values between 15 and 25.
#    - The majority of the values fall in the range of 10 to 30.
#
# 3. **perimeter_mean**:
#    - The distribution is similar to `radius_mean`, showing a right-skewed pattern.
#    - Most values are between 60 and 100, with some outliers extending beyond 120.
#
# 4. **area_mean**:
#    - This feature has a strong right-skewed distribution, with most values below 1000.
#    - A few outliers have values greater than 2000.
#
# 5. **smoothness_mean**:
#    - The distribution is slightly right-skewed but relatively more uniform compared to other features.
#    - Most values are between 0.08 and 0.12.
#
# ### Summary
#
# - The histograms provide a visual representation of the distribution of selected features.
# - Most features exhibit a right-skewed distribution, indicating that a majority of the values are concentrated towards the lower end of the scale, with fewer outliers at the higher end.
# - Understanding the distribution of features helps in identifying potential outliers and understanding the range and central tendency of the data, which is crucial for further analysis and model building.

# %% [markdown]
# ### Step 2.2 Analyze Correlations Between Features
#
# In this step, we'll analyze the correlations between features to identify significant relationships.

# %%
# Compute the correlation matrix
corr_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Feature Correlation Matrix', fontsize=16)
plt.show()

# %% [markdown]
# **Observations from the Output:**
#
# #### Analysis of Feature Correlations
#
# - **High Positive Correlations**:
#   - **radius_mean, perimeter_mean, and area_mean**:
#     - These three features exhibit very high positive correlations with each other, all above 0.9.
#     - This indicates that as the `radius_mean` increases, both `perimeter_mean` and `area_mean` also increase proportionally.
#   - **concavity_mean and concave points_mean**:
#     - These two features also show a high positive correlation (0.88), suggesting a strong linear relationship.
#
# - **Diagnosis Correlations**:
#   - The `diagnosis` column, which is our target variable, shows:
#     - A high positive correlation with `radius_mean` (0.73), `perimeter_mean` (0.74), `area_mean` (0.71), and `concave points_mean` (0.78).
#     - A lower, but still positive correlation with features like `concavity_mean` (0.70) and `compactness_mean` (0.60).
#   - These positive correlations imply that higher values of these features are more likely associated with malignant tumors.
#
# - **Moderate Correlations**:
#   - Features such as `texture_mean` and `smoothness_mean` show moderate positive correlations with `diagnosis`.
#   - These features also correlate moderately with other features like `compactness_mean` and `concavity_mean`.
#
# - **Low Correlations**:
#   - Some features like `symmetry_mean` and `fractal_dimension_mean` show lower correlations with `diagnosis` and other features.
#   - These low correlations suggest that these features might not be as influential in predicting the `diagnosis`.
#
# - **Negative Correlations**:
#   - There are no significant negative correlations observed in this heatmap.
#   - Most correlations are either positive or close to zero.
#
# ### Summary
#
# - The heatmap reveals significant positive correlations between certain features, particularly `radius_mean`, `perimeter_mean`, and `area_mean`.
# - High correlations between the target variable `diagnosis` and features like `radius_mean`, `perimeter_mean`, and `concave points_mean` suggest these features are important for predicting whether a tumor is malignant or benign.
# - Understanding these correlations helps in feature selection and engineering, guiding us on which features might be most valuable for building effective machine learning models.

# %% [markdown]
# ### Step 2.3: Additional Visualizations
#
# In this step, we'll create more visualizations to further explore the data and understand the relationships between features and the target variable (diagnosis). These visualizations will help in identifying patterns, distributions, and correlations in the dataset.
#
# ### Step 2.3.1 Pairplot
#
# A pairplot will help visualize the relationship between different features and the target variable. It provides scatter plots for feature combinations and histograms for individual features.

# %%
# Pairplot
sns.pairplot(df.iloc[:, 1:6], hue="diagnosis")
plt.show()

# %% [markdown]
# ### Observations from the Output:
# #### Pairplot Analysis
#
# 1. **radius_mean**:
#     - There is a clear separation between the two diagnosis classes (0 and 1).
#     - Malignant tumors (class 1) tend to have larger radius_mean values compared to benign tumors (class 0).
#
# 2. **texture_mean**:
#     - The distributions of texture_mean for both classes overlap significantly.
#     - There is no clear separation between benign and malignant tumors based on texture_mean alone.
#
# 3. **perimeter_mean**:
#     - Similar to radius_mean, there is a noticeable separation between the two classes.
#     - Malignant tumors tend to have larger perimeter_mean values.
#
# 4. **area_mean**:
#     - There is a strong separation between the two classes, with malignant tumors generally having larger area_mean values.
#     - This feature shows a clear distinction, similar to radius_mean and perimeter_mean.
#
# #### Scatter Plot Analysis
#
# 1. **radius_mean vs. perimeter_mean**:
#     - There is a strong linear relationship between these two features.
#     - Malignant tumors (orange points) are clustered at higher values, while benign tumors (blue points) are at lower values.
#
# 2. **radius_mean vs. area_mean**:
#     - There is a positive correlation, with malignant tumors having higher values for both features.
#     - This scatter plot also shows a clear distinction between the two classes.
#
# 3. **texture_mean vs. other features**:
#     - The scatter plots involving texture_mean and other features do not show a strong linear relationship.
#     - The separation between classes is not as clear as it is for radius_mean, perimeter_mean, and area_mean.
#
# ### Summary
#
# - The pairplot provides a visual representation of the relationships between different features and the target variable (diagnosis).
# - Features like radius_mean, perimeter_mean, and area_mean show a clear distinction between benign and malignant tumors.
# - Understanding these visual patterns helps in identifying which features are most informative for distinguishing between classes, which is crucial for building effective machine learning models.

# %% [markdown]
# ### Step 2.3.2 Boxplot
#
# Boxplots for different features grouped by the target variable (diagnosis). This will help in understanding the distribution of features for benign (0) and malignant (1) tumors.

# %%
# Boxplot for radius_mean, texture_mean, and area_mean grouped by diagnosis
plt.figure(figsize=(15, 10))

plt.subplot(3, 1, 1)
sns.boxplot(x='diagnosis', y='radius_mean', data=df)
plt.title('Boxplot of radius_mean by Diagnosis')

plt.subplot(3, 1, 2)
sns.boxplot(x='diagnosis', y='texture_mean', data=df)
plt.title('Boxplot of texture_mean by Diagnosis')

plt.subplot(3, 1, 3)
sns.boxplot(x='diagnosis', y='area_mean', data=df)
plt.title('Boxplot of area_mean by Diagnosis')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations from the Output:
# Boxplot Analysis
#
# 1. **radius_mean by Diagnosis**:
#     - The boxplot shows a clear distinction between benign (0) and malignant (1) tumors.
#     - Malignant tumors have a higher median radius_mean compared to benign tumors.
#     - There are several outliers in both classes, but the spread of radius_mean values is greater in malignant tumors.
#
# 2. **texture_mean by Diagnosis**:
#     - The median texture_mean for malignant tumors is slightly higher than for benign tumors.
#     - There is more overlap in texture_mean values between the two classes compared to radius_mean.
#     - Both classes have several outliers, but the overall distribution is similar.
#
# 3. **area_mean by Diagnosis**:
#     - There is a significant difference in the median area_mean between benign and malignant tumors.
#     - Malignant tumors have a much higher median area_mean.
#     - The spread of area_mean values is larger in malignant tumors, with several high-value outliers.
#
# ### Summary
# - The boxplots provide a visual comparison of feature distributions for benign and malignant tumors.
# - Features like radius_mean and area_mean show a clear distinction between the two classes, with higher median values for malignant tumors.
# - Texture_mean, while still informative, shows more overlap between the two classes.
# - Understanding these distributions helps in identifying which features are most discriminative for distinguishing between benign and malignant tumors, aiding in the feature selection process for building machine learning models.

# %% [markdown]
# ### Step 2.3.3 Violin Plot
#
# Violin plots can also be used to show the distribution of features for benign and malignant tumors, giving more insight into the data distribution and density.

# %%
# Violin plot for radius_mean, texture_mean, and area_mean grouped by diagnosis
plt.figure(figsize=(15, 10))

plt.subplot(3, 1, 1)
sns.violinplot(x='diagnosis', y='radius_mean', data=df)
plt.title('Violin Plot of radius_mean by Diagnosis')

plt.subplot(3, 1, 2)
sns.violinplot(x='diagnosis', y='texture_mean', data=df)
plt.title('Violin Plot of texture_mean by Diagnosis')

plt.subplot(3, 1, 3)
sns.violinplot(x='diagnosis', y='area_mean', data=df)
plt.title('Violin Plot of area_mean by Diagnosis')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observations from the Output:
# #### Violin Plot Analysis
#
# 1. **Radius_mean**:
#    - The violin plot for `radius_mean` shows a clear distinction between benign (diagnosis 0) and malignant (diagnosis 1) tumors.
#    - Benign tumors have a narrower and more peaked distribution, concentrating around lower radius values.
#    - Malignant tumors display a wider distribution with a higher median and more values spread across a larger range, indicating larger radii in malignant cases.
#
# 2. **Texture_mean**:
#    - For `texture_mean`, both benign and malignant distributions are broader, with overlapping values.
#    - The plot shapes are less distinct between the two diagnoses compared to `radius_mean`, but malignant tumors tend to have a slightly higher median texture value.
#
# 3. **Area_mean**:
#    - The `area_mean` shows a significant difference in distribution shapes and spread between benign and malignant tumors.
#    - Benign tumors exhibit a sharp peak with a narrow spread, mainly concentrated at lower area values.
#    - Malignant tumors have a much broader distribution with higher values, indicating larger tumor areas in malignant cases.
#
# #### Summary
# - Violin plots provide a detailed visualization of the data distribution and density across benign and malignant tumors.
# - They help in visually assessing the spread and skewness of data points, showing not just the range but also the density of data at different values.
# - Such plots are particularly useful for understanding how features vary with the diagnosis and can help in identifying features with strong discriminatory power, such as `radius_mean` and `area_mean`.

# %% [markdown]
# ### Step 2.3.4 Countplot
#
# A countplot for the diagnosis variable to show the number of benign and malignant cases.

# %%
# Countplot for diagnosis
sns.countplot(x='diagnosis', data=df)
plt.title('Countplot of Diagnosis')
plt.show()

# %% [markdown]
# ### Observations from the Output:
# #### Countplot Analysis
#
# 1. **Diagnosis Distribution**:
#    - The countplot for the diagnosis variable shows the distribution of benign (0) and malignant (1) cases in the dataset.
#    - There are more benign cases (around 350) compared to malignant cases (around 200).
#    - This indicates that the dataset is imbalanced, with a higher proportion of benign tumors.
#
# #### Summary
# - The countplot provides a visual representation of the class distribution in the dataset.
# - It highlights the class imbalance, which is important to consider when developing and evaluating machine learning models.
# - Handling imbalanced datasets often requires specific techniques such as resampling (oversampling the minority class or undersampling the majority class), using different evaluation metrics, or applying algorithms that are robust to class imbalance.

# %% [markdown]
# ## **Model Training and Evaluation**
#
# In this step, we will implement, train, and evaluate various machine learning models. We will compare their performances using metrics such as accuracy, precision, recall, and F1-score, and select the best-performing model based on these evaluation results.

# %% [markdown]
# ### Step 3.1 Split the Data
#
# We'll start by splitting the dataset into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

# Separate the features and labels
X = df.iloc[:, 2:].values
y = df.iloc[:, 1].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Verify the split
print("Training set size:", X_train.shape)
print("Testing set size:", X_test.shape)
# Out:
# Training set size: (455, 30)
# Testing set size: (114, 30)

# %% [markdown]
# ### Step 3.2 Logistic Regression
#
# We will first train and evaluate a Logistic Regression model.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd

# Load the dataset
df = pd.read_csv("data.csv")

# Check for missing values and drop any columns with all NaN values
df = df.dropna(axis=1)

# Encode the 'diagnosis' column to numerical values
labelencoder_Y = LabelEncoder()
df.iloc[:, 1] = labelencoder_Y.fit_transform(df.iloc[:, 1].values)

# Separate the features and labels
X = df.iloc[:, 2:31].values
Y = df.iloc[:, 1].values

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# Scale the features
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Ensure the target variable is of integer type
Y_train = Y_train.astype(int)
Y_test = Y_test.astype(int)

# Train the logistic regression model
lr = LogisticRegression(random_state=0)
lr.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred_lr = lr.predict(X_test)

# Evaluate the model
accuracy_lr = accuracy_score(Y_test, y_pred_lr)
precision_lr = precision_score(Y_test, y_pred_lr)
recall_lr = recall_score(Y_test, y_pred_lr)
f1_lr = f1_score(Y_test, y_pred_lr)

print("Logistic Regression Performance:")
print("Accuracy:", accuracy_lr)
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1-Score:", f1_lr)
# Out:
# Logistic Regression Performance:
# Accuracy: 0.956140350877193
# Precision: 0.9565217391304348
# Recall: 0.9361702127659575
# F1-Score: 0.946236559139785

# %% [markdown]
# ### Observations
#
# The Logistic Regression model has shown the following performance metrics on the testing set:
#
# - Accuracy: 95.61%
# - Precision: 95.56%
# - Recall: 93.62%
# - F1-Score: 94.57%
#
# These metrics indicate that the Logistic Regression model performs well in distinguishing between benign and malignant tumors.

# %% [markdown]
# ### Step 3.3 Decision Tree
#
# We will now train and evaluate a Decision Tree model.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Train the decision tree model
dt = DecisionTreeClassifier(random_state=0)
dt.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred_dt = dt.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(Y_test, y_pred_dt)
precision_dt = precision_score(Y_test, y_pred_dt)
recall_dt = recall_score(Y_test, y_pred_dt)
f1_dt = f1_score(Y_test, y_pred_dt)

print("Decision Tree Performance:")
print("Accuracy:", accuracy_dt)
print("Precision:", precision_dt)
print("Recall:", recall_dt)
print("F1-Score:", f1_dt)
# Out:
# Decision Tree Performance:
# Accuracy: 0.9122807017543859
# Precision: 0.8627450980392157
# Recall: 0.9361702127659575
# F1-Score: 0.8979591836734694

# %% [markdown]
# ### Observations
#
# The Decision Tree model has shown the following performance metrics on the testing set:
#
#     Accuracy: 91.23%
#     Precision: 86.25%
#     Recall: 93.62%
#     F1-Score: 89.80%
#
# #### Detailed Analysis
#
# 1. **Accuracy (91.23%)**:
#     - This metric indicates that the model correctly classified 91.23% of the instances in the test set.
#     - While it is lower than the Logistic Regression model's accuracy, it still indicates a strong performance.
#
# 2. **Precision (86.25%)**:
#     - Precision is the ratio of correctly predicted positive observations to the total predicted positives.
#     - A precision of 86.25% means that when the Decision Tree model predicts a tumor as malignant, it is correct 86.25% of the time.
#
# 3. **Recall (93.62%)**:
#     - Recall is the ratio of correctly predicted positive observations to the all observations in the actual class.
#     - With a recall of 93.62%, the Decision Tree model successfully identifies 93.62% of all malignant tumor cases in the test set.
#
# 4. **F1-Score (89.80%)**:
#     - The F1-Score is the harmonic mean of precision and recall.
#     - An F1-Score of 89.80% indicates a balance between precision and recall, suggesting that the Decision Tree model performs well in identifying malignant tumors with a good balance between precision and recall.
#
# #### Summary
#
# - The Decision Tree model demonstrates strong performance with high recall, making it effective in identifying most malignant tumors.
# - However, its precision is slightly lower compared to Logistic Regression, which means it has more false positives.
# - The overall performance of the Decision Tree model is good, but it might be slightly less robust than Logistic Regression for this particular dataset.

# %% [markdown]
# ### Step 3.4 Random Forest
#
# Finally, we will train and evaluate a Random Forest model.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Train the Random Forest model
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(Y_test, y_pred_rf)
precision_rf = precision_score(Y_test, y_pred_rf)
recall_rf = recall_score(Y_test, y_pred_rf)
f1_rf = f1_score(Y_test, y_pred_rf)

print("Random Forest Performance:")
print("Accuracy:", accuracy_rf)
print("Precision:", precision_rf)
print("Recall:", recall_rf)
print("F1-Score:", f1_rf)
# Out:
# Random Forest Performance:
# Accuracy: 0.9649122807017544
# Precision: 0.9387755102040817
# Recall: 0.9787234042553191
# F1-Score: 0.9583333333333334

# %% [markdown]
# ### Observations
#
# The Random Forest model has shown the following performance metrics on the testing set:
#
# - Accuracy: 96.49%
# - Precision: 93.88%
# - Recall: 97.82%
# - F1-Score: 95.83%
#
# #### Detailed Analysis
#
# 1. **Accuracy (96.49%)**:
#     - This metric indicates that the model correctly classified 96.49% of the instances in the test set.
#     - The Random Forest model outperforms both the Logistic Regression and Decision Tree models in terms of accuracy.
#
# 2. **Precision (93.88%)**:
#     - Precision is the ratio of correctly predicted positive observations to the total predicted positives.
#     - A precision of 93.88% means that when the Random Forest model predicts a tumor as malignant, it is correct 93.88% of the time.
#     - This precision is higher than that of the Decision Tree model and slightly higher than the Logistic Regression model.
#
# 3. **Recall (97.82%)**:
#     - Recall is the ratio of correctly predicted positive observations to all observations in the actual class.
#     - With a recall of 97.82%, the Random Forest model successfully identifies 97.82% of all malignant tumor cases in the test set.
#     - The recall is significantly higher than both the Logistic Regression and Decision Tree models.
#
# 4. **F1-Score (95.83%)**:
#     - The F1-Score is the harmonic mean of precision and recall.
#     - An F1-Score of 95.83% indicates a good balance between precision and recall, suggesting that the Random Forest model performs exceptionally well in identifying malignant tumors.
#
# #### Summary
#
# - The Random Forest model demonstrates the best overall performance compared to Logistic Regression and Decision Tree models.
# - It achieves the highest accuracy, precision, recall, and F1-Score, making it the most robust model for this dataset.
# - With high precision and recall, the Random Forest model is effective in correctly identifying malignant tumors while minimizing false positives.

# %% [markdown]
# ## **Model Comparison and Selection**
#
# In this step, we will compare the performance metrics of the Logistic Regression, Decision Tree, and Random Forest models to select the best-performing model.

# %% [markdown]
# ### Step 4.1 Comparison of Model Performance

# %% [markdown]
# | Metric       | Logistic Regression | Decision Tree | Random Forest |
# |--------------|---------------------|---------------|---------------|
# | Accuracy     | 95.61%              | 91.23%        | 96.49%        |
# | Precision    | 95.56%              | 86.25%        | 93.88%        |
# | Recall       | 93.62%              | 93.62%        | 97.82%        |
# | F1-Score     | 94.57%              | 89.80%        | 95.83%        |

# %% [markdown]
# ### Step 4.2 Selection of the Best Model
#
# Based on the performance metrics, the Random Forest model is selected as the best-performing model. It achieves the highest accuracy, precision, recall, and F1-Score, making it the most robust model for this dataset.

# %% [markdown]
# ## **Conclusion**
#
# In this project, we performed data preprocessing, exploratory data analysis, and trained multiple machine learning models to classify tumors as benign or malignant based on their features. The Random Forest model emerged as the best performer, demonstrating high accuracy and reliability in classification tasks.
#
# By employing this model, healthcare professionals can potentially improve the accuracy of breast cancer diagnoses, leading to better patient outcomes.
